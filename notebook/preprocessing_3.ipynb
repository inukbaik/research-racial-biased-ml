# %%
import pandas as pd

data1 = pd.read_csv('data_county.csv')
data1.head()
# Out:
#    Unnamed: 0  Data as of  Start Date    End Date  \
# 0           0  09/27/2023  01/01/2020  09/23/2023
# 1           1  09/27/2023  01/01/2020  09/23/2023
# 2           2  09/27/2023  01/01/2020  09/23/2023
# 3           3  09/27/2023  01/01/2020  09/23/2023
# 4           4  09/27/2023  01/01/2020  09/23/2023
#
#                            Location  Urban Rural Code  FIPS State  \
# 0        Anchorage Municipality, AK                 3           2
# 1        Anchorage Municipality, AK                 3           2
# 2        Anchorage Municipality, AK                 3           2
# 3  Fairbanks North Star Borough, AK                 4           2
# 4  Fairbanks North Star Borough, AK                 4           2
#
#    FIPS County  FIPS Code                             Indicator  Total deaths  \
# 0           20       2020  Distribution of all-cause deaths (%)          9439
# 1           20       2020   Distribution of COVID-19 deaths (%)          9439
# ...

# %%
data2 = pd.read_csv('income_per_capita_proc.csv')
data2.head()
# Out:
#    Unnamed: 0     Location     2020     2021     2022  Income_per_Capita
# 0           0  Autauga, AL  45151.0  48914.0  49391.0       47818.666667
# 1           1  Baldwin, AL  51230.0  55865.0  56747.0       54614.000000
# 2           2  Barbour, AL  37111.0  40795.0  40560.0       39488.666667
# 3           3     Bibb, AL  34938.0  37175.0  37513.0       36542.000000
# 4           4   Blount, AL  38133.0  42852.0  43744.0       41576.333333

# %%
data = pd.merge(data1, data2, on='Location')
data.head()
# Out:
#    Unnamed: 0_x  Data as of  Start Date    End Date  \
# 0             0  09/27/2023  01/01/2020  09/23/2023
# 1             1  09/27/2023  01/01/2020  09/23/2023
# 2             2  09/27/2023  01/01/2020  09/23/2023
# 3             3  09/27/2023  01/01/2020  09/23/2023
# 4             4  09/27/2023  01/01/2020  09/23/2023
#
#                            Location  Urban Rural Code  FIPS State  \
# 0        Anchorage Municipality, AK                 3           2
# 1        Anchorage Municipality, AK                 3           2
# 2        Anchorage Municipality, AK                 3           2
# 3  Fairbanks North Star Borough, AK                 4           2
# 4  Fairbanks North Star Borough, AK                 4           2
#
#    FIPS County  FIPS Code                             Indicator  ...  \
# 0           20       2020  Distribution of all-cause deaths (%)  ...
# 1           20       2020   Distribution of COVID-19 deaths (%)  ...
# ...

# %%
data.drop(columns=['Unnamed: 0_x', 'Data as of', 'Unnamed: 0_y'], inplace=True)
data.head()
# Out:
#    Start Date    End Date                          Location  Urban Rural Code  \
# 0  01/01/2020  09/23/2023        Anchorage Municipality, AK                 3
# 1  01/01/2020  09/23/2023        Anchorage Municipality, AK                 3
# 2  01/01/2020  09/23/2023        Anchorage Municipality, AK                 3
# 3  01/01/2020  09/23/2023  Fairbanks North Star Borough, AK                 4
# 4  01/01/2020  09/23/2023  Fairbanks North Star Borough, AK                 4
#
#    FIPS State  FIPS County  FIPS Code                             Indicator  \
# 0           2           20       2020  Distribution of all-cause deaths (%)
# 1           2           20       2020   Distribution of COVID-19 deaths (%)
# 2           2           20       2020        Distribution of population (%)
# 3           2           90       2090  Distribution of all-cause deaths (%)
# 4           2           90       2090   Distribution of COVID-19 deaths (%)
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3477 entries, 0 to 3476
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Start Date                                              3477 non-null   object
#  1   End Date                                                3477 non-null   object
#  2   Location                                                3477 non-null   object
#  3   Urban Rural Code                                        3477 non-null   int64
#  4   FIPS State                                              3477 non-null   int64
#  5   FIPS County                                             3477 non-null   int64
#  6   FIPS Code                                               3477 non-null   int64
#  7   Indicator                                               3477 non-null   object
# ...

# %%
data.to_csv('completed_data.csv')
