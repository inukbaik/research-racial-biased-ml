# %%
import pandas as pd

# Load the dataset
file_path = 'deaths.csv'
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#    Data as of  Start Date    End Date State                   County Name  \
# 0  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 1  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 2  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 3  09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
# 4  09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
#
#    Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                 3           2           20       2020
# 1                 3           2           20       2020
# 2                 3           2           20       2020
# 3                 4           2           90       2090
# 4                 4           2           90       2090
#
#                               Indicator  ...  COVID-19 Deaths  \
# 0  Distribution of all-cause deaths (%)  ...              787
# ...

# %%
data['Location'] = data['County Name'] + ', ' + data['State']
data.tail()
# Out:
#       Data as of  Start Date    End Date State        County Name  \
# 3682  09/27/2023  01/01/2020  09/23/2023    WY    Sheridan County
# 3683  09/27/2023  01/01/2020  09/23/2023    WY    Sheridan County
# 3684  09/27/2023  01/01/2020  09/23/2023    WY  Sweetwater County
# 3685  09/27/2023  01/01/2020  09/23/2023    WY  Sweetwater County
# 3686  09/27/2023  01/01/2020  09/23/2023    WY  Sweetwater County
#
#       Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 3682                 5          56           33      56033
# 3683                 5          56           33      56033
# 3684                 5          56           37      56037
# 3685                 5          56           37      56037
# 3686                 5          56           37      56037
#
#                                  Indicator  ...  Non-Hispanic White  \
# 3682   Distribution of COVID-19 deaths (%)  ...               0.861
# 3683        Distribution of population (%)  ...               0.913
# ...

# %%
data.drop('State', axis=1, inplace=True)
data.drop('County Name', axis=1, inplace=True)
data.head()
# Out:
#    Data as of  Start Date    End Date  Urban Rural Code  FIPS State  \
# 0  09/27/2023  01/01/2020  09/23/2023                 3           2
# 1  09/27/2023  01/01/2020  09/23/2023                 3           2
# 2  09/27/2023  01/01/2020  09/23/2023                 3           2
# 3  09/27/2023  01/01/2020  09/23/2023                 4           2
# 4  09/27/2023  01/01/2020  09/23/2023                 4           2
#
#    FIPS County  FIPS Code                             Indicator  Total deaths  \
# 0           20       2020  Distribution of all-cause deaths (%)          9439
# 1           20       2020   Distribution of COVID-19 deaths (%)          9439
# 2           20       2020        Distribution of population (%)          9439
# 3           90       2090  Distribution of all-cause deaths (%)          2257
# 4           90       2090   Distribution of COVID-19 deaths (%)          2257
#
#    COVID-19 Deaths  Non-Hispanic White  Non-Hispanic Black  \
# ...

# %%
data.columns
# Out:
# Index(['Data as of', 'Start Date', 'End Date', 'Urban Rural Code',
#        'FIPS State', 'FIPS County', 'FIPS Code', 'Indicator', 'Total deaths',
#        'COVID-19 Deaths', 'Non-Hispanic White', 'Non-Hispanic Black',
#        'Non-Hispanic American Indian or Alaska Native', 'Non-Hispanic Asian',
#        'Non-Hispanic Native Hawaiian or Other Pacific Islander', 'Hispanic',
#        'Other', 'Urban Rural Description', 'Footnote', 'Location'],
#       dtype='object')

# %%
new_order = ['Data as of', 'Start Date', 'End Date', 'Location', 'Urban Rural Code',
       'FIPS State', 'FIPS County', 'FIPS Code', 'Indicator', 'Total deaths',
       'COVID-19 Deaths', 'Non-Hispanic White', 'Non-Hispanic Black',
       'Non-Hispanic American Indian or Alaska Native', 'Non-Hispanic Asian',
       'Non-Hispanic Native Hawaiian or Other Pacific Islander', 'Hispanic',
       'Other', 'Urban Rural Description']
data = data[new_order]
data.head()
# Out:
#    Data as of  Start Date    End Date                          Location  \
# 0  09/27/2023  01/01/2020  09/23/2023        Anchorage Municipality, AK
# 1  09/27/2023  01/01/2020  09/23/2023        Anchorage Municipality, AK
# 2  09/27/2023  01/01/2020  09/23/2023        Anchorage Municipality, AK
# 3  09/27/2023  01/01/2020  09/23/2023  Fairbanks North Star Borough, AK
# 4  09/27/2023  01/01/2020  09/23/2023  Fairbanks North Star Borough, AK
#
#    Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                 3           2           20       2020
# 1                 3           2           20       2020
# 2                 3           2           20       2020
# 3                 4           2           90       2090
# 4                 4           2           90       2090
#
#                               Indicator  Total deaths  COVID-19 Deaths  \
# 0  Distribution of all-cause deaths (%)          9439              787
# ...

# %%
data.to_csv('data_county.csv')

# %%
file_path2 = 'income_per_capita.csv'
data2 = pd.read_csv(file_path2)
data2.head()
# Out:
#       Location   2020   2021   2022
# 0  Autauga, AL  45151  48914  49391
# 1  Baldwin, AL  51230  55865  56747
# 2  Barbour, AL  37111  40795  40560
# 3     Bibb, AL  34938  37175  37513
# 4   Blount, AL  38133  42852  43744

# %%
data2['2020'] = pd.to_numeric(data2['2020'], errors='coerce')
data2['2021'] = pd.to_numeric(data2['2021'], errors='coerce')
data2['2022'] = pd.to_numeric(data2['2022'], errors='coerce')

data2['Income_per_Capita'] = data2[['2020', '2021', '2022']].mean(axis=1)
data2.head()
# Out:
#       Location     2020     2021     2022  Income_per_Capita
# 0  Autauga, AL  45151.0  48914.0  49391.0       47818.666667
# 1  Baldwin, AL  51230.0  55865.0  56747.0       54614.000000
# 2  Barbour, AL  37111.0  40795.0  40560.0       39488.666667
# 3     Bibb, AL  34938.0  37175.0  37513.0       36542.000000
# 4   Blount, AL  38133.0  42852.0  43744.0       41576.333333

# %%
data2.to_csv('income_per_capita_proc.csv')

# %%
data['Location'] = data['Location'].str.replace(r'\sCounty,', ',', regex=True)
# Out:
#    Data as of  Start Date    End Date                          Location  \
# 0  09/27/2023  01/01/2020  09/23/2023        Anchorage Municipality, AK
# 1  09/27/2023  01/01/2020  09/23/2023        Anchorage Municipality, AK
# 2  09/27/2023  01/01/2020  09/23/2023        Anchorage Municipality, AK
# 3  09/27/2023  01/01/2020  09/23/2023  Fairbanks North Star Borough, AK
# 4  09/27/2023  01/01/2020  09/23/2023  Fairbanks North Star Borough, AK
#
#    Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                 3           2           20       2020
# 1                 3           2           20       2020
# 2                 3           2           20       2020
# 3                 4           2           90       2090
# 4                 4           2           90       2090
#
#                               Indicator  Total deaths  COVID-19 Deaths  \
# 0  Distribution of all-cause deaths (%)          9439              787
# ...

# %%
data.tail()
# Out:
#       Data as of  Start Date    End Date        Location  Urban Rural Code  \
# 3682  09/27/2023  01/01/2020  09/23/2023    Sheridan, WY                 5
# 3683  09/27/2023  01/01/2020  09/23/2023    Sheridan, WY                 5
# 3684  09/27/2023  01/01/2020  09/23/2023  Sweetwater, WY                 5
# 3685  09/27/2023  01/01/2020  09/23/2023  Sweetwater, WY                 5
# 3686  09/27/2023  01/01/2020  09/23/2023  Sweetwater, WY                 5
#
#       FIPS State  FIPS County  FIPS Code  \
# 3682          56           33      56033
# 3683          56           33      56033
# 3684          56           37      56037
# 3685          56           37      56037
# 3686          56           37      56037
#
#                                  Indicator  Total deaths  COVID-19 Deaths  \
# 3682   Distribution of COVID-19 deaths (%)          1247              101
# 3683        Distribution of population (%)          1247              101
# ...

# %%
data.to_csv('data_county.csv')
